# %%
import pandas as pd

circa_df = pd.read_csv('circa.tsv', sep='\t', na_filter = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13847/1598417329.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 circa_df = pd.read_csv('circa.tsv', sep='\t', na_filter = False)
#       4
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
circa_df.iloc[10]
# Out:
# id                                                              10
# context          Y has just told X that he/she is thinking of b...
# question-X                            Is the apartment big enough?
# canquestion-X                        The apartment is big enough .
# answer-Y                                 All of my stuff will fit.
# judgements       Probably yes / sometimes yes#Probably yes / so...
# goldstandard1                         Probably yes / sometimes yes
# goldstandard2                                                  Yes
# Name: 10, dtype: object

# %%
all_gold_labels = list(circa_df.iloc[:]['goldstandard2'])

# %%
set(all_gold_labels)
# Out:
# {'In the middle, neither yes nor no',
#  'NA',
#  'No',
#  'Other',
#  'Yes',
#  'Yes, subject to some conditions'}

# %%
ans_set_strict = list(circa_df.iloc[:]['goldstandard1'])

# %%
ans_set_strict
# Out:
# {'I am not sure how X will interpret Y’s answer',
#  'In the middle, neither yes nor no',
#  'No',
#  'Other',
#  'Probably no',
#  'Probably yes / sometimes yes',
#  'Yes',
#  'Yes, subject to some conditions',
#  nan}

# %%
all_gold_labels
# Out:
# ['Yes',
#  'No',
#  'No',
#  'Yes',
#  'In the middle, neither yes nor no',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  nan,
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes, subject to some conditions',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes, subject to some conditions',
#  'Yes',
#  'No',
#  'No',
#  nan,
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'In the middle, neither yes nor no',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'Yes, subject to some conditions',
#  'Yes',
#  'Yes',
#  'Yes, subject to some conditions',
#  'Yes',
#  'No',
#  'Yes',
#  'In the middle, neither yes nor no',
#  'Yes',
#  'Yes, subject to some conditions',
#  'No',
#  'No',
#  'Yes',
#  'Yes, subject to some conditions',
#  'No',
#  'Yes',
#  'Yes',
#  'In the middle, neither yes nor no',
#  'Yes',
# ...

# %%
from collections import Counter
Counter(all_gold_labels)
# Out:
# Counter({'Yes': 16628,
#          'No': 12833,
#          'In the middle, neither yes nor no': 949,
#          'NA': 771,
#          'Yes, subject to some conditions': 2583,
#          'Other': 504})

# %%
Counter(ans_set_strict)
# Out:
# Counter({'Yes': 14504,
#          'No': 10829,
#          'In the middle, neither yes nor no': 638,
#          'Probably yes / sometimes yes': 1244,
#          'Probably no': 1160,
#          'NA': 2743,
#          'Yes, subject to some conditions': 2583,
#          'Other': 504,
#          'I am not sure how X will interpret Y’s answer': 63})
